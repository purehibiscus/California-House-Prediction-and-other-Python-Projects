# %%
import pandas as pd

gpu_category = df
df = pd.read_csv(r'C:\Users\nadanee\Desktop\MY CASE STUDES\Unclenaned datasets\MySQL_laptop EDA\gpu category.csv')

# %%
print(df.head(2))
# Out:
#                     GPU  AvgPrice  Count
# 0     NVIDIA GTX Series  149131.0      1
# 1  NVIDIA Quadro Series  131079.0     30

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the summarized CSV file
gpu_category = pd.read_csv(r'C:\Users\nadanee\Desktop\MY CASE STUDES\Unclenaned datasets\MySQL_laptop EDA\gpu category.csv')

# Plotting
fig, ax1 = plt.subplots()

# Bar chart for counts
ax1.bar(gpu_category['GPU'], gpu_category['Count'], color='skyblue', label='Counts')
ax1.set_ylabel('Counts', color='skyblue')
ax1.set_xlabel('GPU Categories')

plt.xticks(rotation=90)

# Line chart for average price
ax2 = ax1.twinx()
ax2.plot(gpu_category['GPU'], gpu_category['AvgPrice'], color='orange', label='Avg Price', marker='o')
ax2.set_ylabel('Avg Price ($)', color='orange')

# Titles and layout
plt.title('Laptop GPU Categories by Avg Price and Counts')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt 
import pandas as pd

#Load the summarized CSV file
laptop_median_price = pd.read_csv(r'C:\Users\nadanee\Desktop\MY CASE STUDES\Unclenaned datasets\MySQL_laptop EDA\laptop median price.csv')

#Plotting
fig, ax1 = plt.subplots()

#Bar chart for counts
ax1.bar(laptop_median_price['company'], laptop_median_price['Count'], color='skyblue', label='Counts')
ax1.set_ylabel('Counts', color='skyblue')
ax1.set_xlabel('Laptop Companies')

plt.xticks(rotation=90)

#Line chart for average price
ax2 = ax1.twinx()
ax2.plot(laptop_median_price['company'], laptop_median_price['medianPrice'], color='orange', label='median Price', marker='o')
ax2.set_ylabel('Median Price ($)', color='orange')

#Titles and layout
plt.title('Laptop median Price across Companies')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the summarized CSV file
laptop_OS = pd.read_csv(r'C:\Users\nadanee\Desktop\MY CASE STUDES\Unclenaned datasets\MySQL_laptop EDA\laptop os.csv')

# Plotting
fig, ax1 = plt.subplots()

# Bar chart for counts
ax1.bar(laptop_OS['OS'], laptop_OS['Count'], color='skyblue', label='Counts')
ax1.set_ylabel('Counts', color='skyblue')
ax1.set_xlabel('Laptop sale OS Categories')

plt.xticks(rotation=90)

# Line chart for average price
ax2 = ax1.twinx()
ax2.plot(laptop_OS['OS'], laptop_OS['AvgPrice'], color='orange', label='Avg Price', marker='o')
ax2.set_ylabel('Avg Price ($)', color='orange')

# Titles and layout
plt.title('Laptop OS Categories by Average Price and Counts')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the summarized CSV file
CPU_performance = pd.read_csv(r'C:\Users\nadanee\Desktop\MY CASE STUDES\Unclenaned datasets\MySQL_laptop EDA\CPU performance.csv')

# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for counts
ax1.bar(CPU_performance['CPU Category'], CPU_performance['Count'], color='skyblue', label='Counts')
ax1.set_ylabel('Counts', color='skyblue')
ax1.set_xlabel('Laptop CPU Categories')
plt.xticks(rotation=90)

# Line chart for average price
ax2 = ax1.twinx()
ax2.plot(CPU_performance['CPU Category'], CPU_performance['AvgPrice'], color='orange', label='Avg Price', marker='o')
ax2.set_ylabel('Avg Price ($)', color='orange')

# Line chart for average weight
ax2.plot(CPU_performance['CPU Category'], CPU_performance['AvgWeight'], color='red', label='Avg Weight', marker='o')

# Titles and layout
plt.title('CPU Categories by Count, Average Price, and Average Weight')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the summarized CSV file
popular_GPU_RAM = pd.read_csv(r'C:\Users\nadanee\Desktop\MY CASE STUDES\Unclenaned datasets\MySQL_laptop EDA\popular GPU and RAM.csv')

# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for counts
ax1.bar(popular_GPU_RAM['GPU'], popular_GPU_RAM['Count'], color='skyblue', label='Counts')
ax1.set_ylabel('Counts', color='skyblue')
ax1.set_xlabel('Laptop GPU Categories')
plt.xticks(rotation=90)

# Line chart for average price
ax2 = ax1.twinx()
ax2.plot(popular_GPU_RAM['GPU'], popular_GPU_RAM['AvgRAM'], color='orange', label='Avg RAM', marker='o')
ax2.set_ylabel('Avg RAM (GB)', color='orange')

# Line chart for average weight
ax2.plot(popular_GPU_RAM['GPU'], popular_GPU_RAM['Count'], color='red', label='Count', marker='o')

# Titles and layout
plt.title('GPU Categories by Count & Average RAM')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the summarized CSV file
Laptop_Price_bin = pd.read_csv(r'C:\Users\nadanee\Desktop\MY CASE STUDES\Unclenaned datasets\MySQL_laptop EDA\laptop price bin.csv')

# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for counts
ax1.bar(Laptop_Price_bin['Bin'], Laptop_Price_bin['Bin'], color='skyblue', label='Bins')
ax1.set_ylabel('Bin', color='skyblue')
ax1.set_xlabel('Price bins')
plt.xticks(rotation=90)

# Line chart for average price
ax2 = ax1.twinx()
ax2.plot(Laptop_Price_bin['Bin'], Laptop_Price_bin['Percentage_of_Total (%)'], color='orange', label='Percentage of Total(%)', marker='o')
ax2.set_ylabel('Percentage_of_Total (%)', color='orange')

# Line chart for average weight
ax2.plot(Laptop_Price_bin['Bin'], Laptop_Price_bin['count'], color='red', label='count', marker='o')

# Titles and layout
plt.title('Laptop Price Bin Distribution')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
fig.tight_layout()
plt.show()

# %%
import pandas as pd

Laptop_Price_bin = pd.read_csv(r'C:\Users\nadanee\Desktop\MY CASE STUDES\Unclenaned datasets\MySQL_laptop EDA\laptop price bin.csv')
df = Laptop_Price_bin
print(df.head(5))
# Out:
#   Bin  count  Percentage_of_Total (%)
# 0   A    900                72.405500
# 1   B    315                25.341900
# 2   C     24                 1.930810
# 3   D      4                 0.321802
